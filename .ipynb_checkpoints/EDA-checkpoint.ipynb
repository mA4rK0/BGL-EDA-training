# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from imblearn import under_sampling
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
# Edit Parameter default matplotlib
from matplotlib import rcParams
rcParams["figure.figsize"] = (12, 6)
rcParams["lines.linewidth"] = 3
rcParams["xtick.labelsize"] = "x-large"
rcParams["ytick.labelsize"] = "x-large"

# %%
# Read dataset
df = pd.read_csv("botak.csv")
df.shape

# (rows, columns)
# Out:
# (7917, 14)

# %%
df = pd.read_csv("botak.csv").sample(1000)
df.shape
# Out:
# (1000, 14)

# %%
df.sample(10)
# Out:
#       umur jenis_kelamin       pekerjaan    provinsi          gaji  \
# 4836  25.0     Laki-laki             PNS  Banda Aceh  2.212292e+07
# 4638  40.0     Laki-laki             PNS     Jakarta  8.469621e+06
# 2605  36.0     Perempuan       Freelance      Mamuju  1.440646e+07
# 2553  36.0     Laki-laki  Pegawai swasta     Kendari  1.024186e+07
# 7603  25.0     Laki-laki             PNS    Surabaya  1.204229e+07
# 2114  49.0     Laki-laki             PNS  Yogyakarta  6.945625e+06
# 2173  27.0     Laki-laki       Freelance  Banda Aceh  1.052199e+07
# 227   35.0     Laki-laki  Pegawai swasta     Kendari  1.500609e+07
# 2061  49.0     Perempuan             PNS      Padang  8.114909e+06
# 4535  43.0     Perempuan             PNS    Jayapura  7.598210e+06
#
#       is_menikah  is_keturunan      berat      tinggi            sampo  \
# 4836         1.0           0.0  46.071441  164.164080         Moonsilk
# 4638         1.0           1.0  64.538568  173.569564          Pantone
# 2605         1.0           0.0  56.544863  161.708421          Pantone
# 2553         1.0           1.0  57.442461  165.824458  Shoulder & Head
# 7603         1.0           0.0  68.619121  175.824500          Pantone
# 2114         1.0           0.0  48.065454  167.211488          Pantone
# 2173         1.0           0.0  57.982692  153.075478          Merpati
# 227          1.0           0.0  44.171386  150.860756         Moonsilk
# 2061         1.0           0.0  52.580695  165.084393         Deadbuoy
# 4535         1.0           0.0  54.550064  187.736209         Moonsilk
#
#       is_merokok pendidikan  stress  botak_prob
# 4836         0.0         S2     8.0    0.632210
# 4638         0.0        SMP     2.0    0.673449
# 2605         1.0         S1    10.0    0.418979
# 2553         0.0         S1     8.0    0.725210
# 7603         0.0        SMP    10.0    0.578433
# 2114         0.0         S1     6.0    0.518467
# 2173         0.0         S1     3.0    0.292159
# 227          1.0         S1     6.0    0.529213
# 2061         1.0        SMA     5.0    0.667223
# 4535         1.0        SMA     2.0    0.577183

# %%
df.info() # Column 0-12 = predictor/features; Column 13 = target
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 3722 to 3898
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   umur           993 non-null    float64
#  1   jenis_kelamin  992 non-null    object
#  2   pekerjaan      976 non-null    object
#  3   provinsi       988 non-null    object
#  4   gaji           993 non-null    float64
#  5   is_menikah     990 non-null    float64
#  6   is_keturunan   993 non-null    float64
#  7   berat          991 non-null    float64
#  8   tinggi         994 non-null    float64
#  9   sampo          989 non-null    object
#  10  is_merokok     988 non-null    float64
#  11  pendidikan     993 non-null    object
#  12  stress         991 non-null    float64
#  13  botak_prob     990 non-null    float64
# dtypes: float64(9), object(5)
# memory usage: 117.2+ KB

# %%
df.isna().sum()
# Out:
# umur              7
# jenis_kelamin     8
# pekerjaan        24
# provinsi         12
# gaji              7
# is_menikah       10
# is_keturunan      7
# berat             9
# tinggi            6
# sampo            11
# is_merokok       12
# pendidikan        7
# stress            9
# botak_prob       10
# dtype: int64

# %%
df.describe()
# Out:
#              umur          gaji  is_menikah  is_keturunan       berat  \
# count  993.000000  9.930000e+02  990.000000    993.000000  991.000000
# mean    39.066465  8.931209e+06    0.970707      0.199396   55.745551
# std     10.374617  4.633564e+06    0.168712      0.399747    9.942690
# min     -1.000000  1.706443e+06    0.000000      0.000000   40.000000
# 25%     32.000000  5.598315e+06    1.000000      0.000000   49.299679
# 50%     39.000000  7.913822e+06    1.000000      0.000000   53.525386
# 75%     47.000000  1.116926e+07    1.000000      0.000000   60.135579
# max     71.000000  4.297255e+07    1.000000      1.000000  150.000000
#
#            tinggi  is_merokok      stress  botak_prob
# count  994.000000  988.000000  991.000000  990.000000
# mean   167.100664    0.478745    5.313824    0.573440
# std     11.174251    0.499801    2.854980    0.173715
# min    134.411561    0.000000    1.000000    0.082186
# 25%    159.454903    0.000000    3.000000    0.447944
# 50%    167.512161    0.000000    5.000000    0.565336
# 75%    174.993184    1.000000    8.000000    0.685558
# max    226.454577    1.000000   10.000000    1.000000

# %%
cat = ["jenis_kelamin", "pekerjaan", "provinsi", "sampo", "pendidikan"] # categorical data
num = ["umur", "gaji", "is_keturunan", "is_menikah", "berat", "tinggi", "is_merokok", "stress", "botak_prob"] #numerical data

# %%
df[num].describe()
# if mean ~~ median(50%) OR ~~ mode = Normal Distribution = Good Data
# double tilde sign (~~) (near)
# umur, tinggi, stress, botak_prob = normal distribution
# Out:
#              umur          gaji  is_keturunan  is_menikah       berat  \
# count  993.000000  9.930000e+02    993.000000  990.000000  991.000000
# mean    39.066465  8.931209e+06      0.199396    0.970707   55.745551
# std     10.374617  4.633564e+06      0.399747    0.168712    9.942690
# min     -1.000000  1.706443e+06      0.000000    0.000000   40.000000
# 25%     32.000000  5.598315e+06      0.000000    1.000000   49.299679
# 50%     39.000000  7.913822e+06      0.000000    1.000000   53.525386
# 75%     47.000000  1.116926e+07      0.000000    1.000000   60.135579
# max     71.000000  4.297255e+07      1.000000    1.000000  150.000000
#
#            tinggi  is_merokok      stress  botak_prob
# count  994.000000  988.000000  991.000000  990.000000
# mean   167.100664    0.478745    5.313824    0.573440
# std     11.174251    0.499801    2.854980    0.173715
# min    134.411561    0.000000    1.000000    0.082186
# 25%    159.454903    0.000000    3.000000    0.447944
# 50%    167.512161    0.000000    5.000000    0.565336
# 75%    174.993184    1.000000    8.000000    0.685558
# max    226.454577    1.000000   10.000000    1.000000

# %%
# if the min probability is minus, there is something wrong with the probability.

# %%
df[cat].describe() #unique = total type; top = mode; freq = mode frequency
# Out:
#        jenis_kelamin pekerjaan  provinsi     sampo pendidikan
# count            992       976       988       989        993
# unique             2         4        34         5          6
# top        Laki-laki       PNS  Jayapura  Deadbuoy         S1
# freq             688       413        36       215        528

# %%
# if the total unique is high, the column will becomes useless for predict. Because, it will lower the accuracy. In the example above, provinsi is useless

# %%
# value counting
for col in cat:
    print(f'''value count column {col} :''')
    print(df[col].value_counts())
    print()
# Out:
# value count column jenis_kelamin :
# jenis_kelamin
# Laki-laki    688
# Perempuan    304
# Name: count, dtype: int64
#
# value count column pekerjaan :
# pekerjaan
# PNS               413
# Pegawai swasta    379
# Freelance         132
# Pengangguran       52
# Name: count, dtype: int64
#
# value count column provinsi :
# provinsi
# Jayapura          36
# Makassar          35
# Ambon             34
# Palu              34
# Pontianak         34
# Pangkalpinang     33
# Jambi             32
# Palangkaraya      32
# Tanjung Pinang    32
# Tanjungselor      32
# Padang            31
# Banda Lampung     31
# Serang            31
# Manokwari         31
# Banda Aceh        30
# Bengkulu          30
# Kendari           30
# Medan             30
# Mamuju            29
# Gorontalo         27
# Palembang         27
# Surabaya          27
# Manado            27
# Mataram           26
# Jakarta           26
# Pekanbaru         26
# Kupang            26
# Bandung           26
# Sofifi            26
# Denpasar          26
# Banjarmasin       25
# Semarang          25
# Yogyakarta        23
# Samarinda         18
# Name: count, dtype: int64
#
# value count column sampo :
# sampo
# Deadbuoy           215
# Pantone            204
# Moonsilk           199
# Shoulder & Head    187
# Merpati            184
# Name: count, dtype: int64
#
# value count column pendidikan :
# pendidikan
# S1     528
# SMA    281
# S2      71
# SMP     70
# SD      27
# S3      16
# Name: count, dtype: int64

# %%
# univariate analysis
# boxplot
plt.figure(figsize=(16, 8))

for i, col in enumerate(num):
    plt.subplot(3, 3, i + 1)
    sns.boxplot(x=df[col], color="blue")
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
# dots = outliers
# is_keturunan and is_merokok doesn't have outlier because there are only 2 values
# is_merokok values is balanced (50/50)
# gaji and berat graphs is skewed to the right (positive skewed), because the outliers going to the right direction
# graph is skewed to the left (negative skewed), because the outliers going to the left direction

# %%
# hist plot
# if umur ~~ normal dist., fill the umur missing data with mean
# if gaji = skewed, fill the gaji missing data with median (50%)
plt.figure(figsize=(16, 8))

for i, col in enumerate(num):
    plt.subplot(3, 3, i + 1)
    sns.histplot(data=df, x=col, kde=True, color="red")
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
# violin plot (optional) = boxplot + histplot
plt.figure(figsize=(16, 8))

for i, col in enumerate(num):
    plt.subplot(3, 3, i + 1)
    sns.violinplot(x=df[col], color="yellow")
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
# count plot: categorical (cat)
plt.figure(figsize=(16, 10))

for i, col in enumerate(cat):
    plt.subplot(2, 3, i + 1)
    sns.countplot(
        data=df,
        x=col,
        color="orange"
    )
    plt.title(col)
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# bivariate analysis
# correlation heatmap 
plt.figure(figsize=(8, 8))
corr_matrix = df.select_dtypes(include="number").corr()

sns.heatmap(
    corr_matrix,
    cmap="Reds",
    annot=True,
    fmt=".2f"
)

plt.show()

# %%
# look at the target variable first (botak_prob), if the correlation values is higher than or equal to 0.5. It means that is high correlation
# if the 2 features variable has high correlation (>=0.5), that means it is biased values. Delete a biased feature.

# %%
# pair plot
plt.figure(figsize=(10, 10))
sns.pairplot(
    df,
    diag_kind="kde"
)
plt.show()

# %%
plt.figure(figsize=(14, 12))

for i, col in enumerate(num):
    plt.subplot(3, 3, i + 1)
    sns.stripplot(
        data=df,
        x="jenis_kelamin",
        y=col,
        jitter=True,
        alpha=0.5
    )

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 12))

for i, col in enumerate(num):
    plt.subplot(3, 3, i + 1)
    sns.stripplot(
        data=df,
        x="pekerjaan",
        y=col,
        jitter=True,
        alpha=0.5
    )

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 12))

for i, col in enumerate(num):
    plt.subplot(3, 3, i + 1)
    sns.stripplot(
        data=df,
        x="sampo",
        y=col,
        jitter=True,
        alpha=0.5
    )

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 12))

for i, col in enumerate(num):
    plt.subplot(3, 3, i + 1)
    sns.stripplot(
        data=df,
        x="pendidikan",
        y=col,
        jitter=True,
        alpha=0.5
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# ## EDA Conclusion

# %% [markdown]
# Some things we find from this EDA dataset are:
# - The data looks valid and there are no defects
# - However, there is still empty/missing data, which must be taken care of during preprocessing
# - There are some distributions that are slightly skewed, this must be remembered if we want to do something or use a model requires the assumption of a normal distribution
# - Some features have a clear correlation with the target, they will be used
# - Some features seem completely uncorrelated, they are best ignored or modified

# %% [markdown]
# ## Excited Data Preparation

# %%
data1 = pd.read_csv("botak.csv")
data1.shape
# Out:
# (7917, 14)

# %%
data1.sample(10)
# Out:
#       umur jenis_kelamin       pekerjaan    provinsi          gaji  \
# 3136  48.0     Laki-laki    Pengangguran      Serang  1.936803e+07
# 3223  34.0     Laki-laki       Freelance     Kendari  1.184324e+07
# 3150  40.0     Laki-laki             PNS   Palembang  2.712971e+06
# 6879  41.0     Laki-laki             PNS      Sofifi  5.593899e+06
# 5966  42.0     Laki-laki    Pengangguran   Manokwari  2.401929e+07
# 6464  44.0     Laki-laki  Pegawai swasta     Mataram  9.763713e+06
# 1835  48.0     Laki-laki       Freelance    Denpasar  5.156668e+06
# 5872  48.0     Laki-laki  Pegawai swasta      Padang  1.861712e+07
# 2550  20.0     Laki-laki  Pegawai swasta  Banda Aceh  1.303407e+07
# 2466  51.0     Perempuan             PNS    Denpasar  1.079906e+07
#
#       is_menikah  is_keturunan      berat      tinggi            sampo  \
# 3136         1.0           0.0  54.019247  193.348439          Merpati
# 3223         1.0           0.0  54.130254  193.425747          Pantone
# 3150         1.0           0.0  50.996449  157.682498         Deadbuoy
# 6879         1.0           0.0  46.554135  177.481413         Deadbuoy
# 5966         1.0           0.0  46.317361  168.588924  Shoulder & Head
# 6464         1.0           0.0  63.114097         NaN          Merpati
# 1835         1.0           0.0  51.477654  170.900410          Merpati
# 5872         1.0           0.0  56.158001  150.800188          Pantone
# 2550         1.0           0.0  62.742788  183.422911          Pantone
# 2466         1.0           0.0  58.135913  168.790336          Merpati
#
#       is_merokok pendidikan  stress  botak_prob
# 3136         1.0         S1     5.0    0.985380
# 3223         0.0         S2     5.0    0.313144
# 3150         1.0         SD     2.0    0.554428
# 6879         0.0         S1     6.0    0.627220
# 5966         1.0         SD     3.0    0.926831
# 6464         1.0        SMA     7.0    0.296895
# 1835         1.0         S1     9.0    0.674009
# 5872         1.0         SD     2.0    0.520848
# 2550         1.0         S1     4.0    0.515951
# 2466         0.0         S1     7.0    0.621281

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7917 entries, 0 to 7916
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   umur           7838 non-null   float64
#  1   jenis_kelamin  7840 non-null   object
#  2   pekerjaan      7760 non-null   object
#  3   provinsi       7831 non-null   object
#  4   gaji           7843 non-null   float64
#  5   is_menikah     7845 non-null   float64
#  6   is_keturunan   7828 non-null   float64
#  7   berat          7861 non-null   float64
#  8   tinggi         7843 non-null   float64
#  9   sampo          7858 non-null   object
#  10  is_merokok     7847 non-null   float64
#  11  pendidikan     7847 non-null   object
#  12  stress         7853 non-null   float64
#  13  botak_prob     7838 non-null   float64
# dtypes: float64(9), object(5)
# memory usage: 866.1+ KB

# %%
data1.isna().sum()
# Out:
# umur              79
# jenis_kelamin     77
# pekerjaan        157
# provinsi          86
# gaji              74
# is_menikah        72
# is_keturunan      89
# berat             56
# tinggi            74
# sampo             59
# is_merokok        70
# pendidikan        70
# stress            64
# botak_prob        79
# dtype: int64

# %%
data1.dropna(subset=["berat", "sampo", "stress", "jenis_kelamin", "gaji", "is_menikah", "tinggi", "is_merokok", "pendidikan"], inplace=True)
data1.isna().sum()
# Out:
# umur              72
# jenis_kelamin      0
# pekerjaan        143
# provinsi          77
# gaji               0
# is_menikah         0
# is_keturunan      85
# berat              0
# tinggi             0
# sampo              0
# is_merokok         0
# pendidikan         0
# stress             0
# botak_prob        67
# dtype: int64

# %%
# imputasi numerik
data1["umur"] = data1["umur"].fillna(data1["umur"].mean())
data1["is_keturunan"] = data1["is_keturunan"].fillna(0)
data1["botak_prob"] = data1["botak_prob"].fillna(data1["botak_prob"].median())

# %%
data1.isna().sum()
# Out:
# umur               0
# jenis_kelamin      0
# pekerjaan        143
# provinsi          77
# gaji               0
# is_menikah         0
# is_keturunan       0
# berat              0
# tinggi             0
# sampo              0
# is_merokok         0
# pendidikan         0
# stress             0
# botak_prob         0
# dtype: int64

# %%
# imputasi categorical
data1["pekerjaan"] = data1["pekerjaan"].fillna(data1["pekerjaan"].mode()[0])
data1["provinsi"] = data1["provinsi"].fillna(data1["provinsi"].mode()[0])

# %%
data1.isna().sum()
# Out:
# umur             0
# jenis_kelamin    0
# pekerjaan        0
# provinsi         0
# gaji             0
# is_menikah       0
# is_keturunan     0
# berat            0
# tinggi           0
# sampo            0
# is_merokok       0
# pendidikan       0
# stress           0
# botak_prob       0
# dtype: int64

# %%
print(data1.duplicated().sum())
data1.drop_duplicates(inplace=True)
print(data1.duplicated().sum())
# Out:
# 75
# 0

# %%
# handle outlier
# use z-score (recommended)
print(f"jumlah baris sebelum difilter: {len(data1)}")

filtered_entries = np.array([True] * len(data1))
for col in ["umur", "gaji", "tinggi", "berat"]:
    zscore = abs(stats.zscore(data1[col]))
    filtered_entries = (zscore < 3) & filtered_entries
data2 = data1[filtered_entries]

print(f"jumlah baris setelah difilter: {len(data2)}")
# Out:
# jumlah baris sebelum difilter: 7244
# jumlah baris setelah difilter: 6973

# %%
# use IQR
# print(f"jumlah baris sebelum difilter: {len(data1)}")

#filtered_entries = np.array([True] * len(data1))
#for col in ["umur", "gaji", "tinggi", "berat"]:
    #Q1 = data1[col].quantile(0.25)
    #Q3 = data1[col].quantile(0.75)
    #IQR = Q3 - Q1
    #low = Q1 - (IQR * 1.5)
    #high = Q3 - (IQR * 1.5)

    #filtered_entries = ((data1[col] >= low) & (data1[col] <= high)) & filtered_entries
#data3 = data1[filtered_entries]
#print(f"jumlah baris setelah difilter: {len(data3)}")

# %%
data1.describe()
# Out:
#               umur          gaji   is_menikah  is_keturunan        berat  \
# count  7244.000000  7.244000e+03  7244.000000   7244.000000  7244.000000
# mean     39.479554  8.822688e+06     0.979155      0.203341    55.927132
# std       9.910214  4.468649e+06     0.142875      0.402512     9.517581
# min      -1.000000  1.500000e+06     0.000000      0.000000    40.000000
# 25%      33.000000  5.712932e+06     1.000000      0.000000    49.312233
# 50%      39.484614  7.808108e+06     1.000000      0.000000    53.842407
# 75%      46.000000  1.080876e+07     1.000000      0.000000    60.230478
# max      77.000000  5.000000e+07     1.000000      1.000000   126.042823
#
#             tinggi   is_merokok       stress   botak_prob
# count  7244.000000  7244.000000  7244.000000  7244.000000
# mean    167.232886     0.497377     5.448509     0.573784
# std      10.925550     0.500028     2.862339     0.172500
# min     125.491784     0.000000     1.000000     0.064633
# 25%     159.745779     0.000000     3.000000     0.454197
# 50%     167.134895     0.000000     5.000000     0.567887
# 75%     174.423427     1.000000     8.000000     0.685689
# max     211.285582     1.000000    10.000000     1.000000

# %%
# use MinMaxScaler() when a variable is skewed. Use StandardScaler when a variable is close to normal distribution
data1["berat_norm"] = MinMaxScaler().fit_transform(data1["berat"].values.reshape(len(data1), 1))
data1["gaji_norm"] = MinMaxScaler().fit_transform(data1["gaji"].values.reshape(len(data1), 1))
data1["botak_norm"] = MinMaxScaler().fit_transform(data1["botak_prob"].values.reshape(len(data1), 1))

# %%
data1.describe()
# Out:
#               umur          gaji   is_menikah  is_keturunan        berat  \
# count  7244.000000  7.244000e+03  7244.000000   7244.000000  7244.000000
# mean     39.479554  8.822688e+06     0.979155      0.203341    55.927132
# std       9.910214  4.468649e+06     0.142875      0.402512     9.517581
# min      -1.000000  1.500000e+06     0.000000      0.000000    40.000000
# 25%      33.000000  5.712932e+06     1.000000      0.000000    49.312233
# 50%      39.484614  7.808108e+06     1.000000      0.000000    53.842407
# 75%      46.000000  1.080876e+07     1.000000      0.000000    60.230478
# max      77.000000  5.000000e+07     1.000000      1.000000   126.042823
#
#             tinggi   is_merokok       stress   botak_prob   berat_norm  \
# count  7244.000000  7244.000000  7244.000000  7244.000000  7244.000000
# mean    167.232886     0.497377     5.448509     0.573784     0.185107
# std      10.925550     0.500028     2.862339     0.172500     0.110614
# min     125.491784     0.000000     1.000000     0.064633     0.000000
# 25%     159.745779     0.000000     3.000000     0.454197     0.108228
# 50%     167.134895     0.000000     5.000000     0.567887     0.160878
# 75%     174.423427     1.000000     8.000000     0.685689     0.235121
# max     211.285582     1.000000    10.000000     1.000000     1.000000
#
#          gaji_norm   botak_norm
# count  7244.000000  7244.000000
# mean      0.150983     0.544333
# std       0.092137     0.184420
# min       0.000000     0.000000
# 25%       0.086865     0.416482
# 50%       0.130064     0.538028
# 75%       0.191933     0.663971
# max       1.000000     1.000000

# %%
# feature encoding
for cat in [["provinsi", "jenis_kelamin", "pekerjaan"]]:
    onehots= pd.get_dummies(data1[cat], prefix = cat)
    dc = data1.join(onehots)

# %%
dc.describe()
# Out:
#               umur          gaji   is_menikah  is_keturunan        berat  \
# count  7244.000000  7.244000e+03  7244.000000   7244.000000  7244.000000
# mean     39.479554  8.822688e+06     0.979155      0.203341    55.927132
# std       9.910214  4.468649e+06     0.142875      0.402512     9.517581
# min      -1.000000  1.500000e+06     0.000000      0.000000    40.000000
# 25%      33.000000  5.712932e+06     1.000000      0.000000    49.312233
# 50%      39.484614  7.808108e+06     1.000000      0.000000    53.842407
# 75%      46.000000  1.080876e+07     1.000000      0.000000    60.230478
# max      77.000000  5.000000e+07     1.000000      1.000000   126.042823
#
#             tinggi   is_merokok       stress   botak_prob   berat_norm  \
# count  7244.000000  7244.000000  7244.000000  7244.000000  7244.000000
# mean    167.232886     0.497377     5.448509     0.573784     0.185107
# std      10.925550     0.500028     2.862339     0.172500     0.110614
# min     125.491784     0.000000     1.000000     0.064633     0.000000
# 25%     159.745779     0.000000     3.000000     0.454197     0.108228
# 50%     167.134895     0.000000     5.000000     0.567887     0.160878
# 75%     174.423427     1.000000     8.000000     0.685689     0.235121
# max     211.285582     1.000000    10.000000     1.000000     1.000000
#
#          gaji_norm   botak_norm
# count  7244.000000  7244.000000
# mean      0.150983     0.544333
# std       0.092137     0.184420
# min       0.000000     0.000000
# 25%       0.086865     0.416482
# 50%       0.130064     0.538028
# 75%       0.191933     0.663971
# max       1.000000     1.000000

# %%
# imbalance dataset
# True = > 0.8
# False = < 0.8
data1["botak_class"] = data1["botak_prob"] > 0.8
data1["botak_class"].value_counts()
# Out:
# botak_class
# False    6492
# True      752
# Name: count, dtype: int64

# %%
x = data1[[col for col in data1.columns if (str(data1[col].dtype) != "object") and col not in ["botak_prob", "botak_class"]]]
y = data1["botak_class"].values
print(x.shape)
print(y.shape)
# Out:
# (7244, 11)
# (7244,)

# %%
x_under, y_under = under_sampling.RandomUnderSampler().fit_resample(x,y)
pd.Series(y_under).value_counts()
# Out:
# False    752
# True     752
# Name: count, dtype: int64
